# %%
inventario={ 
'laptop':5,
'mouse': 12,
'teclado':8
}
#actualizar_inventario
def actualizar_inventario(
        inventario:dict[str,int],
        producto: str,
        cantidad: int,
        operacion: str 
) -> dict [str, str | int]:
    operaciones = ["entrada","salida"]
    if operacion not in operaciones: 
        return {
            "mensaje": f"Error, tipo de operacion no soportada: {operacion}"
        }
    
    if not isinstance (cantidad, int) and cantidad <0:
        return {
            "mensaje": "error, tipo de dato no adeacuado"        
            }
    if cantidad <0:
        return {
            "mensaje":"error,la cantidad es negativa"
        }
    print ("comprobacion exitosa")


actualizar_inventario(inventario,"mouse",-1,"entrada")
# Out:
# {'mensaje': 'Error, tipo de operacion no soportada: actualizacion'}

# %%
texto='aaabbccccdaa'
def comprimir_texto(texto:str) -> str:
    resultado=[]
    caracter_actual=texto[0]
    contador = 1
    for caracter in texto[1:]:
        if caracter == caracter_actual:
            contador+=1
        else:
            resultado.append(f"{caracter_actual}{contador}")
            caracter_actuañ=caracter
            contador=1
    return resultado 

texto=  'aaabbccccdaa'
comprimir_texto(texto)
# Out:
# ['a3', 'a1', 'a1', 'a1', 'a1', 'a1', 'a1']
