# %%
import pandas as pd


s = pd.Series([120,85,200,45],
index = ["ene","feb","mar","abr"],
name="ventas)")
print(s["mar"])
# Out:
# 200

# %%
print(s["abr"])
# Out:
# 45

# %%
print (s*1.21)
# Out:
# ene    145.20
# feb    102.85
# mar    242.00
# abr     54.45
# Name: ventas), dtype: float64

# %%
s.mean()
# Out:
# np.float64(112.5)

# %%
s.max()
# Out:
# np.int64(200)

# %%
import  numpy as np

# %%
df=pd.DataFrame({"producto":["Laptop","Monitor","Teclado"]},{"unidades:[3,7,12]"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.DataFrame({"producto":["Laptop","Monitor","Teclado"]},{"unidades:[3,7,12]"})
#
# NameError: name 'pd' is not defined
