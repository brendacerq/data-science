# %%
conjunto_a={1,3,5,7,8,9}
conjunto_b={3,5,7}

conjunto_a.isdisjoint(conjunto_b)
# Out:
# False

# %%
conjunto_a={1,3,5,7,8,9}
conjunto_b={180}

conjunto_a.isdisjoint(conjunto_b)
# Out:
# True

# %%
conjunto_a={1,3,5,7,8,9}
conjunto_b={3,5,7}

conjunto_a.issubset(conjunto_b)
# Out:
# False
