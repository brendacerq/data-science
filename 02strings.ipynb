# %% [markdown]
# -longitud de mi cadena (len)
# -convertir a mayuscula (upper)
# -convertir a minuscula (lower)
# -reemplazar un valor de la cadena (replace)
# -"texto        " -> (strip)-> "texto"
# -"texto1,texto2,texto3" -> (split, ",") -> [texto1, texto2,texto3]
# -

# %%
nombre = "brenda"
print("cuantas letras tiene mi nombre :", len (nombre))
print(len ("peru"))
# Out:
# cuantas letras tiene mi nombre : 6
# 4

# %%
print (nombre.upper())
# Out:
# BRENDA

# %%
print(nombre.lower())
# Out:
# brenda

# %%
print (
    nombre.replace("da","do")
)
# Out:
# brendo

# %%
nombre="brenda     "
print(len(nombre))
nombre_limpio=nombre.strip()
print(len(nombre_limpio))
# Out:
# 11
# 6

# %%
nombres="brenda cerquiera"
nombres_separados = nombres.split(" ")
print (nombres_separados)

nombres ="brendaxxcerquiera"
nombres_separados=nombres.split("xx")
print(nombres_separados)
# Out:
# ['brenda', 'cerquiera']
# ['brenda', 'cerquiera']

# %% [markdown]
# indexacion

# %%
print (nombre[0])
print (nombre[1])
print (nombre[2])
print (nombre[3])

ultima_letra = nombre [3]
print(ultima_letra)
ultima_letra1 = nombre[-1]
print(ultima_letra1)
# Out:
# b
# r
# e
# n
# n
