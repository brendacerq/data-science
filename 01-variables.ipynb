# %%
print("hola mundo")
# Out:
# hola mundo

# %%
#Variable de texto, string 
nom: str
apellido: str
nombre = "Brenda"
apellido = "Cerquiera"

print (nombre + ' ' + apellido)
mi_nombre_completo = f"Mi nombre clompleto es : {nombre} {apellido}"

#Variables numericos enteros o int 
edad: int 
edad= 25 

#Variables numericas pero decimales o float 
sueldo: float = 9.99 

print ("Mi edad dentro de 5 años: ", edad + 5)
print("El doble de mi edad: ", edad * 2)
print ("la mitad de mi edad entera: ", edad // 2 )
print ("el resto de mi edad:", edad % 2)
# Out:
# Brenda Cerquiera
# Mi edad dentro de 5 años:  30
# El doble de mi edad:  50
# la mitad de mi edad entera:  12
# el resto de mi edad: 1

# %%
nombre = input ("ingresa tu edad: ")

# %%
type(edad)
# Out:
# int

# %%
print (edad+ 5 )
# Out:
# 30

# %% [markdown]
# igual o comparacion (==)

# %%
numero_1=30
numero_2=2
numero_3=3 
print(numero_1==numero_2)
print(numero_1==numero_3)
# Out:
# False
# False

# %%
nombre=input ("ingresa tu nombre")
print(f"tu nombre es: {nombre}")
# Out:
# tu nombre es: brenda

# %%
edad="100"

# %%
int(edad)+5
# Out:
# 105

# %%
type(edad)
# Out:
# str
