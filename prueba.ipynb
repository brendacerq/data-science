# %%
porcent_propina : float
total_cuenta: float
Monto_propina : float

total_cuenta=input ("ingresa la cuenta total")
porcent_propina= input("ingresa propina deseado")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 12
#       8 porcent_propina= input("ingresa propina deseado")
#       9
#      10
#      11
# ---> 12 Monto_propina= (total_cuenta) * (porcent_propina)
#      13 print(Monto_propina)
#
# TypeError: can't multiply sequence by non-int of type 'str'
